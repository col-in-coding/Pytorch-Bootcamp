# %% [markdown]
# ![](../img/chinahadoop.png)

# %% [markdown]
# # 课程大纲与说明
# **[小象学院](http://www.chinahadoop.cn/course/landpage/15)《机器学习集训营》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)**

# %% [markdown]
# ## 第1阶段
# **[小象学院](http://www.chinahadoop.cn/course/landpage/15)《机器学习集训营》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)**
# ### 板块1：编程与代码基础
#   - 知识覆盖
#     - AI与python编程语言
#     - 编程环境与操作技巧
#     - 基本python类型
#     - python判断与循环流程
#     - 函数定义
#     - 数据读写
#     - 面向对象编程
#     - 正则表达式与文本模式匹配
#     - 第三方工具库使用(以AI项目为例)
#   - 练习与实训
#     - python基本操作练习题
#     - google python实战题
#     - AI工具库调用与使用练习
#
# ### 板块2：数据分析与可视化
#   - 知识覆盖
#     - 科学计算库Numpy简介
#     - Pandas Series与DataFrame初始化与数据读写
#     - 数据选择与赋值
#     - 数据分组、统计与分析
#     - 常用数据变换与其在机器学习特征工程应用
#     - 多表关联与合并操作
#     - 时间序列数据处理
#     - 基于pandas的可视化
#     - matplotlib可视化与模板
#     - seaborn核心可视化挖掘技能
#     - 数据分析与可视化核心技能回顾与延伸
#
#   - 练习与实训
#     - pandas数据分析操作练习题
#     - matplotlib与seaborn可视化操作练习题
#     - 拉钩招聘信息综合分析挖掘案例
#     - 链家房产数据综合分析挖掘案例
#     - 淘宝电商数据综合分析挖掘案例
#     - 短视频社交数据分析面试题
#
#
# ### 板块3：大数据与海量数据处理
#   - 知识覆盖
#     - 大数据概述与基本生态介绍
#     - hadoop生态介绍
#       - HDFS分布式文件系统
#       - map-reduce大数据并行计算框架
#     - spark生态介绍
#       - spark数据抽象RDD
#       - spark 转换(transformation)与动作(action)
#       - spark DataFrame大数据处理
#       - spark SQL大数据处理
#   - 练习与实训
#     - spark数据处理练习
#     - spark大数据日志分析案例(RDD版本)
#     - spark大数据日志分析案例(DataFrame版本)
#     - 基于Spark SQL的房产数据处理分析
#
# ### 板块4：机器学习/深度学习原理知识
#   - 知识覆盖
#     - 基本模型串讲
#       - 机器学习基本核心概念
#       - 线性模型(LR、softmax)
#       - 树模型(决策树、随机森林、GBDT，Xgboost，LightGBM)
#       - 无监督学习(聚类、降维)
#       - 神经网络(MLP、CNN、RNN/LSTM、)
#     - 特征工程与模型评估调优
#       - 常见特征工程操作与意义
#       - 模型调优方法
#       - 模型选择与实验方法
#       - 模型评估度量准则
#       - 模型集成
#     - 常见面试考点总结
#   - 练习与实训
#     - 机器学习核心知识练习
#     - 深度学习核心知识练习
#
# ### 板块5：AI工具与应用
#   - 知识覆盖
#     - 常用机器学习建模工具库
#       - scikit-learn
#         - sklearn不同板块与使用方法
#         - sklearn基本特征工程+调参模板
#         - 完整的sklearn建模与优化案例
#       - spark mllib
#         - spark mllib特征工程方法
#         - spark mllib监督学习与无监督学习模板
#       - Xgboost
#         - Xgboost功能与参数介绍
#         - Xgboost建模调优模板
#       - LightGBM
#         - LightGBM功能与参数介绍
#         - LightGBM建模调优模板
#       - 案例
#         - 使用sklearn与Xgboost/LightGBM完成电力需求预测
#         - 使用spark mllib完成保险公司未来出险数额预估
#     - 常用深度学习建模工具库
#       - tensorflow与keras
#         - tensorflow high-level API功能介绍
#         - 使用tensorflow+keras搭建网络基本步骤
#         - 卷积神经网络构建与网络可视化等高级功能介绍
#       - pytorch
#       - 案例
#         - 使用tensorflow+keras完成基本图像分类模型搭建案例
#         - 使用tensorflow+keras构建RNN网络完成文本分类案例
#   - 练习与实训
#     - sklearn+Xgboost建模解决链家房价预估练习
#     - tensorflow+keras完成宠物分类案例
#
# ## 第2阶段
# **[小象学院](http://www.chinahadoop.cn/course/landpage/15)《机器学习集训营》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)**
# ### NLP方向
#   - 自然语言处理基本概念与处理环节
#   - 常见中英文数据处理工具库与使用
#   - 典型模型与方法综述
#   - 项目1 文本语种识别模型构建(机器学习)
#   - 项目2 新闻短文本分类(机器学习+深度学习方法)
#   - 项目3 影评数据与电商情感分析(机器学习+深度学习方法)
#   - 项目4 文本自动生成(不同深度学习方法)
#   - 项目5 电商智能客服项目
#   - 项目6 搜索引擎用户画像项目
#   - 项目7 电商数据细粒度文本分类项目
#
# ### CV方向
#   - 标准图像分类模板
#   - 项目1 使用tensorflow+keras快速构建图像分类模型
#   - 项目2 使用tensorflow+keras构建卫星图多任务学习模型并部署服务
#   - 项目3 基于深度学习的电商“以图搜图”图像检索项目构建
#   - 项目4 基于tensorflow的图像物体检测项目
#   - 项目5 交通场景下的车辆精准定位识别项目
#   - 项目6 基于MASK-RCNN的视频图像分割应用项目
#
# ### 电商与资讯公司业务方向
#   - 项目1 京东用户购买预测项目
#   - 项目2 新零售连锁店销量预估项目
#   - 项目3 携程酒店预订预估项目
#   - 项目4 头条内容推荐项目
#   - 项目5 运营商个性化推荐项目
#   - 项目6 腾讯广告精准定向匹配项目
#
# ### 金融与风控方向
#   - 信用评分与风控反作弊业务介绍
#   - 项目1 银行信用评分卡模型构建项目
#   - 项目2 拍拍贷金融风控建模与调优项目
#   - 项目3 马上金融风控建模与调优项目
#   - 项目4 企业经营风险预测建模项目
#   - 项目5 运营商风险用户识别建模项目
#
# ![](../img/ml_process.png)

# %% [markdown]
# ## 学习说明

# %% [markdown]
# - 稳扎稳打，循序渐进
# - 求助助教，解决问题
# - 及时复习，查漏补缺
# - 认真作业，巩固提升
